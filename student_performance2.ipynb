# %%
import pandas as pd

# %%
df = pd.read_csv("Students.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    Name  Age  marks
# 0           0  khushi   20     90
# 1           1    riya   21     90
# 2           2   priya   22     54
# 3           3    diya   23     67
# 4           4   nisha   24     67

# %%
df.shape
# Out:
# (8, 4)

# %%
df.describe()
# Out:
#        Unnamed: 0        Age      marks
# count     8.00000   8.000000   8.000000
# mean      3.50000  23.875000  79.625000
# std       2.44949   3.181981  14.618359
# min       0.00000  20.000000  54.000000
# 25%       1.75000  21.750000  67.000000
# 50%       3.50000  23.500000  89.000000
# 75%       5.25000  25.250000  90.000000
# max       7.00000  30.000000  91.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of    Unnamed: 0    Name  Age  marks
# 0           0  khushi   20     90
# 1           1    riya   21     90
# 2           2   priya   22     54
# 3           3    diya   23     67
# 4           4   nisha   24     67
# 5           5  krisha   25     89
# 6           6  dimpal   26     91
# 7           7   hetvi   30     89>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           0
# marks         0
# dtype: int64

# %%
df["marks"].describe()
# Out:
# count     8.000000
# mean     79.625000
# std      14.618359
# min      54.000000
# 25%      67.000000
# 50%      89.000000
# 75%      90.000000
# max      91.000000
# Name: marks, dtype: float64

# %%
df["marks"].value_counts()
# Out:
# marks
# 90    2
# 67    2
# 89    2
# 54    1
# 91    1
# Name: count, dtype: int64

# %%
df["marks"].hist()
# Out:
# <Axes: >

# %%
print("insight1:the avrege marks are 79.62")
print("insight2:the highest marks are 91 and lowest marks 54")
print("the age column has the highest number of 30")
# Out:
# insight1:the avrege marks are 79.62
# insight2:the highest marks are 91 and lowest marks 54
# the age column has the highest number of 30
